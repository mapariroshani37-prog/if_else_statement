# %%
print("roshani")
# Out:
# roshani

# %%
x=3
x+=x*2
x-=x//2
print(x)

# %%
a =int(input('Enter Number'))
if a<0 :
    print('a is a Negative number')
else:
    print('a is positive number')

# %%
a =int(input("Enter First Number"))
b =int(input("Enter Second Number"))
Operator =input("Enter Operator (+, -,*,/) :)")

if Operator == "+" :
    print("Result = ", a + b )
elif Operator == "-" :
    print("Result = ", a - b )
elif Operator == "*" :
    print("Result = ", a * b )
elif Operator == "/" :
    print("Result = ", a / b )
else :
    print("Invalid Character")
# Out:
# Result =  30

# %%
a = int(input("Enter Marks"))
if a>=90 :
    print("A+")
elif a >=80 and a<90 :
    print("A")
elif a>=70 and a<80 :
    print("b")
elif a>=55 and a<70 :
    print("c")
else :
 print("fail")
# Out:
# c

# %%
a = "DoxproRobotics"
if (a[-9:-12:-1]) in a :
    print("orp present in doxprorobotics")
else :
     print("orp is not present in doxprorobotics")
# Out:
# orp is not present in doxprorobotics

# %%
a =input("Enter The colour").lower()
if a =="red" :
    print("Stop The Car:")
elif a =="yellow" :
    print("Ready To Go")
elif a =="green" :
    print("Go")
else :
    print("Error: Invalid Colour")
# Out:
# Stop The Car:

# %%
a = input("Enter A Digit")
if len(a) ==3 :
    print("Three Digit")
elif len(a)==2 :
    print ("Two Digit")
elif len(a)==1 :
    print("One Digit")
else :
    print("Error:Negative Number")
# Out:
# Three Digit

# %%
a = int(input("enter A Number"))
if a%10==5:
    print("Valid Number")
else :
    print("Invalid Number")
# Out:
# Invalid Number
